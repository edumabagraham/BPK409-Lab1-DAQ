# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ExampleData/Lab1Qu12.txt', sep='\t', header=None, names=['x', 'y', 'z', 't'])

# %%
df.head()
# Out:
#       x     y     z    t
# 0  0.48 -2.18  3.32  542
# 1  0.44 -2.15  3.34  621
# 2  0.45 -2.19  3.32  643
# 3  0.44 -2.18  3.36  663
# 4  0.43 -2.14  3.38  685

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['t'], df['x'], label='X-axis', color='r')
plt.plot(df['t'], df['y'], label='Y-axis', color='g')
plt.plot(df['t'], df['z'], label='Z-axis', color='b')
plt.title('Accelerometer Data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.legend()
plt.grid()
