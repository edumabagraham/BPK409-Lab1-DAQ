# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/home/edumaba/Public/MPhil_Thesis/Activity Classification/BPK409-Lab1-DAQ/ExampleData/Lab1Qu11.txt', sep='\t', header=None, names=['x', 'y', 'z', 't'])

# %%
df.head()
# Out:
#       x     y     z     t
# 0 -0.51 -0.20 -0.82  1440
# 1 -0.52 -0.21 -0.81  1599
# 2 -0.52 -0.21 -0.80  1757
# 3 -0.52 -0.20 -0.82  1915
# 4 -0.51 -0.21 -0.82  2073

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['t'], df['x'], label='X-axis', color='r')
plt.plot(df['t'], df['y'], label='Y-axis', color='g')
plt.plot(df['t'], df['z'], label='Z-axis', color='b')
plt.title('Accelerometer Data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.legend()
plt.grid()
