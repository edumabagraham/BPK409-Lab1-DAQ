# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/home/edumaba/Public/MPhil_Thesis/Activity Classification/BPK409-Lab1-DAQ/ExampleData/Lab1Qu12.txt', sep='\t', header=None, names=['x', 'y', 'z', 't'])

# %%
df['t'] = df['t']/1000
df.head()
# Out:
#       x     y     z      t
# 0  0.48 -2.18  3.32  0.542
# 1  0.44 -2.15  3.34  0.621
# 2  0.45 -2.19  3.32  0.643
# 3  0.44 -2.18  3.36  0.663
# 4  0.43 -2.14  3.38  0.685

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['t'], df['x'], label='X-axis', color='r')
plt.plot(df['t'], df['y'], label='Y-axis', color='g')
plt.plot(df['t'], df['z'], label='Z-axis', color='b')
plt.title('Accelerometer Data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.legend()
plt.grid()

# %% [markdown]
# Visualizing the data as shown in the lab manual.
# They viewed a section of the signal and I divided the time by 1000.

# %%
# Example: filtering for 6.25s to 8s
start_time = 4
end_time = 6.5

# Filter indices where time is within the range
mask = (df['t'] >= start_time) & (df['t'] <= end_time)

# Apply the mask to time and all 3 axis signals
time_zoomed = df['t'][mask]
x_zoomed = df['x'][mask]
y_zoomed = df['y'][mask]
z_zoomed = df['z'][mask]

# %%
plt.figure(figsize=(8, 6))
plt.plot(time_zoomed, x_zoomed, label='x')
plt.plot(time_zoomed, y_zoomed, label='y')
plt.plot(time_zoomed, z_zoomed, label='z')

plt.xlabel('Time [s]')
plt.ylabel('Acc [g]')
plt.title('Lab1 Qu8 Raw Accelerations')
plt.legend()
plt.grid(True)
plt.show()
