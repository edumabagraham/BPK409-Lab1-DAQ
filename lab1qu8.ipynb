# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import pandas as pd
from scipy.signal import butter, filtfilt

# %%
df = pd.read_csv('ExampleData/Lab1Qu8.txt', sep='\t', header=None, names=['x', 'y', 'z', 't'])

# %%
df. head()
# Out:
#       x     y     z     t
# 0  0.19 -0.33 -0.93  2392
# 1  0.19 -0.33 -0.93  2397
# 2  0.20 -0.33 -0.93  2402
# 3  0.19 -0.33 -0.93  2407
# 4  0.19 -0.33 -0.93  2412

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(df['t'], df['x'], label='X-axis', color='b', alpha=0.7)
plt.plot(df['t'], df['y'], label='Y-axis', color='orange', alpha=0.7)
plt.plot(df['t'], df['z'], label='Z-axis', color='g', alpha=0.7)
plt.title('Accelerometer Data')
plt.xlabel('Time (s)')
plt.ylabel('Acceleration (g)')
plt.legend()
plt.grid()
plt.show()
